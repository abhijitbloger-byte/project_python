# %%
class Employee:
    def calculate_net_pay(self):
        pass

    def calculate_bonus(self):
        pass

class HourlyContractor(Employee):

    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_net_pay(self):
        return self.hours_worked * self.hourly_rate

    def calculate_bonus(self):
        return self.calculate_net_pay() * 0.05

class SalariedEmployee(Employee):

    def __init__(self, name, monthly_salary):
        self.name = name
        self.monthly_salary = monthly_salary

    def calculate_net_pay(self):
        return self.monthly_salary

    def calculate_bonus(self):
        return self.monthly_salary * 0.10

def process_monthly_payroll(employee):
    print("\nPayroll Details")
    print("Employee Name:", employee.name)

    print("Net Pay: ₹", employee.calculate_net_pay())
    print("Bonus : ₹", employee.calculate_bonus())

while True:

    print("\n===== PAYROLL SYSTEM =====")
    print("1. Hourly Contractor")
    print("2. Salaried Employee")
    print("3. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":

        name = input("Enter Contractor Name: ")
        hours = float(input("Enter Hours Worked: "))
        rate = float(input("Enter Hourly Rate: ₹"))

        contractor = HourlyContractor(name, hours, rate)

        process_monthly_payroll(contractor)

    elif choice == "2":

        name = input("Enter Employee Name: ")
        salary = float(input("Enter Monthly Salary: ₹"))

        employee = SalariedEmployee(name, salary)

        process_monthly_payroll(employee)

    elif choice == "3":
        print("Exiting Payroll System...")
        break

    else:
        print("Invalid Choice!")
# Out:
# ===== PAYROLL SYSTEM =====
# 1. Hourly Contractor
# 2. Salaried Employee
# 3. Exit
# Enter your choice:  1
# Enter Contractor Name:  Abhijit Pattanaik
# Enter Hours Worked:  8
# Enter Hourly Rate: ₹ 78
# Payroll Details
# Employee Name: Abhijit Pattanaik
# Net Pay: ₹ 624.0
# Bonus : ₹ 31.200000000000003
#
# ===== PAYROLL SYSTEM =====
# 1. Hourly Contractor
# 2. Salaried Employee
# 3. Exit
# Enter your choice:  2
# Enter Employee Name:  Abhijit Pattanaik
# Enter Monthly Salary: ₹ 40000
# Payroll Details
# Employee Name: Abhijit Pattanaik
# Net Pay: ₹ 40000.0
# Bonus : ₹ 4000.0
#
# ===== PAYROLL SYSTEM =====
# 1. Hourly Contractor
# 2. Salaried Employee
# 3. Exit
# Enter your choice:  3
# Exiting Payroll System...
